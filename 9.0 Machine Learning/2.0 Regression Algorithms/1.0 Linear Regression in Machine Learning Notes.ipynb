# %% [markdown]
# # <p style='text-align: center;'> Linear Regression in Machine Learning </p>

# %% [markdown]
# ## Linear Regression :
# - Linear regression makes predictions for continuous or numeric variables such as sales, salary, age, product price, etc.
#
#
# - Linear regression algorithm shows a linear relationship between a dependent (y) and one or more independent (y) variables, hence called as linear regression.
#
#
# - Since linear regression shows the linear relationship, which means it finds how the value of the dependent variable is changing according to the value of the independent variable.
#
#
# - The linear regression model provides a sloped straight line representing the relationship between the variables. Consider the below image :
#
# ![image.png](attachment:image.png)
#
#
# Mathematically, we can represent a linear regression as :
#
#         y = mx + c
#
#
# - Where,
#
#     - y = Dependent Variable (Target Variable)
#     - x = Independent Variable (predictor Variable)
#     - c = intercept of the line (Gives an additional degree of freedom)
#     - m = Linear regression coefficient (Slope : change in y based on change in x).

# %% [markdown]
# ## Types of Linear Regression :
# - Linear regression can be further divided into two types of the algorithm :
#
#     - Simple Linear Regression
#     - Multiple Linear regression

# %% [markdown]
# ## Simple Linear Regression :
# - In simple linear regression, we predict the value of one variable "y" based on another variable "x".
#
#
# - "x" is called the independent variable and "y" is called the dependent variable.
#
#
# - Why Simple : Because it examines relationship between two variables only.
#
#
# - Why Linear : When the independent variable increases (or decreases), the dependent variable increases (or decreases) in a linear fashion.
#
#
# ## Linear Regression Line :
# - A linear line showing the relationship between the dependent and independent variables is called a regression line.
#
#
# - A regression line can show two types of relationship :
#
# **Positive Linear Relationship :**
# - If the dependent variable increases on the Y-axis and independent variable increases on X-axis, then such a relationship is termed as a Positive linear relationship.
#
# ![image.png](attachment:image.png)
#
#
# **Negative Linear Relationship :**
# - If the dependent variable decreases on the Y-axis and independent variable increases on the X-axis, then such a relationship is called a negative linear relationship.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Fundamental Mathematics behind Linear Regression :
# Consider a phenomenon characterized by 2 variables x and y.
#
#
# Here we are creating one DataFrame as "df" with two "x" and "y" variables.

# %%
# import pandas as pd
import pandas as pd

# Create the DataFrame.
df = pd.DataFrame({"x":[1,2,3,4,5],"y":[6,7,8,9,11]})

# Print the DataFrame.
df
# Out:
#    x   y
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  11

# %% [markdown]
# A reasonable start would be to create a scatter plot of the dataset, to get an idea of how y changes with respect to x.
#
#
# Now plotting the scatter plot to get an idea of how y changes with respect to x.

# %%
# import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

#Plot the Scatter plot.
plt.scatter(df["x"], df["y"])

# Set the label for the x-axis.
plt.xlabel("x")

# Set the label for the y-axis.
plt.ylabel("y")

# Display all figures.
plt.show()

# %% [markdown]
# **Goal :** we want to find a line of best fit that links x to y.
#
# The scatter plot suggests that the relationship between x and y is almost linear, hence, we suppose :
#
#     y = B0 + B1*x
#
#
# where :
#
#    - y — represents the output variable, also known as the dependent variable. This is the value you are trying to predict.
#    - B0 — represents the y-intercept (where the line crosses the y axis)
#    - B1 — represents the coefficient of the input variable ‘X’. This value determines the level of influence ‘X’ has upon ‘y’.
#    - x — represents the input variable, also known as the independent variable.
#
#
# Where B0 and B1 are the constants to be determined.
#
#
# This formula can represent an infinite amount of lines based on the values of B0 and B1.
#
#
# Find the values of B0 and B1 for which y(x) best fits the dataset.
#
#
# This is where linear regression comes into play.
#
#
# Linear regression is a model used to achieve establishing a linear relationship between an independent variable, x in our case, and a dependent variable, which is y in our case.
#
#
# When a random sample of observations is given, then the regression line is expressed as ;
#
#     ŷ = B0 + B1*x
#
#
# where :
#
#    - ŷ — ŷ is known as the predicted value of the dependent variable.
#    - B0 — represents the y-intercept (where the line crosses the y axis)
#    - B1 — represents the coefficient of the input variable ‘X’. This value determines the level of influence ‘X’ has upon ‘y’.
#    - x — represents the input variable, also known as the independent variable.
#
#
# ### Ordinary Least squares method :
# Least squares fitting is a way to find the best fit curve or line for a set of points.
#
#
# The least-squares method is one of several methods that can be used to determine the values of the two parameters B0 and B1 based on the dataset.
#
#
# The idea is to calculate the values of B0 and B1 that correspond to the minimum of the sum of squared errors of the offsets (residuals).
#
#
# For every x-value, the Least Squares Regression Line makes a predicted y-value that is close to the observed y-value, but usually slightly off. This predicted y-value is called "y-hat" and symbolized as ŷ. The observed y-value is merely called "y".
#
# ![image-2.png](attachment:image-2.png)
#
#
# **Residuals :**
# Let's take a moment to notice the little gap between the observed y-value (the scatter point labelled y) and the predicted y-value (the point on the line labelled ŷ). This gap is called the residual. The full definition and formula are below :
#
#
# An error is defined as follows :
#
#     Ei = y - ŷ
#
#
# Where :
#
#    - Ei : residual (Error)
#
#    - y : The exact value of y
#
#    - ŷ : The predicted value of y
#
#
# The sum of squared errors (SSE) is defined as :
#
#                  ∑ (y - ŷ)
#     S(B0, B1) = ------------
#                      N
#
#                  ∑ (y - B0 + B1*x)
#     S(B0, B1) = ------------------
#                         N
#
#
# Where N is the number of samples in the dataset, which is 5 in our case.
#
#
# We want to find the values of B0 and B1 for which the function S(B0, B1) is minimized.
#
#
# The extremum (minimum or maximum) of a function can be found by setting the derivative to 0. (as long as the function is differentiable in the R number set).
#
#
# In our case, the error function S(B0, B1) is a polynomial, therefore differentiable in R, so we write :
#
#
#     dS
#     --- = 0 => ∑ 2*x (y - B1*x - B0) = 0
#     dB1
#
#
#     dS
#     --- = 0 => ∑ 2 (y - B1*x - B0) = 0
#     dB0
#
#
# We end up with a homogenous system of equations.
#
#
# Solving these equations yields :
#
#          ∑ (x - x̅) (y - y̅)
#     B1 = -----------------
#            ∑ (x - x̅)^2
#
#
#     B0 = y̅ - B1*x̅
#
#
# Using those equations, now we calculate the optimal values of B0 and B1 for "df" DataFrame :
#
#
# Here we have calculated all necessory calculations in one table :
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Given below is the formula to find the value of the regression coefficient. :
#
#          ∑ (x - x̅) (y - y̅)
#     B1 = -----------------
#            ∑ (x - x̅)^2
#
#
#               12
#     B1 = -----------  = 1.2
#               10
#
# The coefficient of the input variable "X" (slope) is 1.2
#
#     B0 = y̅ - B1*x̅
#
#     B0 = 8.2 - 1.2(3) = 4.6
#
# The y-intercept (B0) is 4.6
#
#
# Hence we got the value of B1 = 1.2  and B0 = 4.6
#
#
# Now calculating a line of best fit that links x to y, the linear equation is given by :
#
#
#     ŷ = B0 + B1*x
#
#
# Now put the value of B0 and B1 in the equation
#
#     ŷ = 4.6 + 1.2(x)
#
#
# <b> Hence equation of linear regression is ŷ = 4.6 + 1.2(x)

# %% [markdown]
# ### Why least-squares ?
# - Why go through the process of squaring the errors before minimizing the error function? why not just sum all the errors?
#
#
# - The problem of summing the errors directly is that errors may be positive or negative. Positive numbers and negative numbers tend to cancel out each other. Say we have an error e1=100 and another error e2=-100; the sum of the two errors (e1+e2=0) suggests that our model is 100% accurate, which is clearly not the case since the errors are just too big.
#
#
# - So before creating the error function, we need to assume that all the errors are positive, therefore, defining the error function as the sum of the errors won’t work. To convert a negative number into a positive one, we usually take the absolute value of the number, or we just square it. So why not take the absolute values of the errors instead?
#
# - This approach could be used and is called the least-absolute deviations method. Although, we often tend to used least-squares in regression analysis, due to the complexity that comes with the differentiation of absolute values.

# %% [markdown]
# <b> In the above we have build Linear Regression model.
#
#
# <b> Now we are going to check the Model Performance (Evaluation).

# %% [markdown]
# --------------------------------------------------
# ## Evaluation metrics in Regression Model :
# --------------------------------------------------

# %% [markdown]
# After model fitting, we would like to access the performance of the model by comparing model predictions to actual (True) data.
#
# Now we have built our Linear Regression model, how do we know if our model has performed well ? There are a few metrics that we can use :
#
#
# **a) MAE (Mean Absolute Error) :**
# - Mean Absolute Error is obtained by calculating the absolute difference between the model predictions and the actual (true) value.
#
#
# - Mean Absolute Error is the average magnitude of error generated by the regression model.
#
#
# - The Mean Absolute Error (MAE) is calculated as follows :
#
#
#             ∑ |y - ŷ)|
#     MAE = --------------
#                 N
#
#
# - MAE is calculated by following these steps :
#
#     1. Calculate the residual of every data point.
#     2. Calculate the Absolute value(to get ridof the sign)
#     3. Calculate the average of all residuals.
#
#
# - If MAE is zero, this indicates that the model predictions are perfect.
#
#
# Here we are not going to calculate the MAE for this dataset, because due to the complexity that comes with the differentiation of absolute values. Here we need to calculate min Error, i.e. we are going with differentiation.

# %% [markdown]
#
# **b) MSE (Mean Squared Error) :**
# - Mean Square Error (MSE) is very similar to the Mean Absolute Error (MAE) but instead of using absolute values, squares of the difference b/w the model predictions and the training dataset (true values) is being calculated.
#
#
# - MSE values are generally larger compared to the MAE since the residuals are being squared.
#
#
# - In case of data outliers, MSE will become much larger compared to MAE.
#
#
# - In MSE, error increases in a quadratic fashion while the error increases in proportional fashion in MAE.
#
#
# - In MSE, since the error is being squared, any predicting error is being heavily penalized.
#
#
# - This is defined by the sum of residuals squared, divided by the total number of data points.
#
#
# - The Mean Squared Error (MSE) is calculated as follows :
#
#
#            ∑ (y - ŷ)^2
#     MSE = --------------
#                 N
#
#
# - MSE is calculated by following these steps :
#
#
#     1. Calculate the residual of every data point.
#     2. Calculate the Squared value of the residuals.
#     3. Calculate the average of results from step-2.
#
#
# Here we have calculated all necessory calculations in one table :
#
#
# ![image.png](attachment:image.png)
#
#
# Now put the value of ∑ (y - ŷ)^2 in the MSE equation :
#
#
#                0.4
#     MSE = -------------- = 0.08
#                 5
#
#
# <b> Mean Squared Error (MSE): 0.08
#
#
# We got the Mean Squared Error (MSE) is 0.08, then we need to calculate the Root Mean Squared Error, because the units get squred here.
#
#
# <b> Now we are going to calculate the Root Mean Squared Error :

# %% [markdown]
# **3. RMSE (Root Mean Squared Error) :**
# - Root Mean Squared Error (RMSE) represents the standard deviation of the residuals (i.e. difference b/w the model predictions and the true values (training data).
#
#
# - RMSE can be easily interpreted compared to MSE, because RMSE units match the units of the output.
#
#
# - RMSE provides an estimate of how large the residuals are being dispersed.
#
#
# - The Root Mean Squared Error (RMSE) is calculated as follows :
#
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# <b> The Root Mean Squared Error (RMSE) is 0.28
#
#
# <b> Here Model Performance (Evaluation) is good, because the error between the actual value and prediction value is 0.28

# %% [markdown]
# ## COEFFICIENT OF DETERMINATION (R^2) :
# - Coefficient of Determination or R-square provides the insight of goodness of fit.
#
#
# - It measures the strength of the relationship between the dependent and independent variables on a scale of 0-100%.
#
#
# - Coefficient of Determination represents the proportion of variance of the dependent variable (y) that has been explained by the independent variables.
#
#
# - The high value of R-square determines the less difference between the predicted values and actual values and hence represents a good model.
#
#
# - It gives a measure of how well unseen samples are likely to be predicted by the model, through the portion of explained variance.
#
#
# - Maximum Coefficient of Determination or R-square (R^2) value is 1.
#
#
# - R^2 value should be lies between 0 to 1, if it decreses to -ve value, then we can say that regression failed.
#
#
# - It is also called a coefficient of determination, or coefficient of multiple determination for multiple regression.
#
#
# - The drawback of using R Squared is the value tends to increase as you add more variables to the model; hence could prove to be a less useful measure.
#
#
# - A constant model that always predicts the expected value of y, disregarding the input features, will have an R^2 score of 0.0
#
#
# - It can be calculated from the below formula :
#
#
#                             Explained variation
#     R-squared (R^2) = 1 - -----------------------
#                               Total variation
#
#
#                               ∑ (y - ŷ)^2
#     R-squared (R^2) = 1 - ---------------------
#                               ∑ (y - y̅)^2
#
#
#
# Here we are calculating ∑ (y - y̅)^2 as follows :
#
#
# ![image.png](attachment:image.png)
#
#
# Now put the values of ∑ (y - ŷ)^2 and ∑ (y - y̅)^2 in the MSE equation :
#
#
#                               0.4
#     R-squared (R^2) = 1 - -----------
#                               14.8
#
#
#
#     R-squared (R^2) = 1 - 0.027 = 0.973
#
#
# Our model has an R-Squared value of 0.973 hence can say our ‘x’ values heavily influence the variation of our ‘y’ values. Here, 97.3% variation in y is explained by x. Here ∑ (y - ŷ)^2 is also called as regression line and ∑ (y - y̅)^2 is called as average line.
#
#
# <b> Hence the high value of R-square determines the less difference between the predicted values and actual values and So it represents a good model.

# %% [markdown]
# ## ADJUSTED R-SQUARED :
# - One limitation of R-square is that it increases by adding independent variables to the model which is misleading since some added variables might be useless with minimul significance.
#
#
# - Adjusted R-squared overcomes this issue by adding a penalty if we make an attemp to add independent variable that does not improve the model.
#
#
# - Adjusted R-squared is a modified version of the R^2 and takes into account the number of predictions in the model.
#
#
# - If useless predictions are added to the model, Adjusted R^2 will decreases.
#
#
# - If usefull predictions are added to the model, Adjusted R^2 will increases.
#
#
# - It can be calculated from the below formula :
#
#
#                           (1 – R^2)(N – 1)
#     (R^2)adjusted = 1 -  --------------------
#                              N – k - 1
#
#
# Where,
#
#    - R^2 : COEFFICIENT OF DETERMINATION or R-squared value.
#    - N   : Number of samples.
#    - k   : Number of independent variables.

# %% [markdown]
# ## Multiple Linear regression :
# - Multiple Linear regression examines relationship between more than two variables.
#
#
# - In Multiple Linear regression, we predict the value of one variable "y" based on multiple variables "x1, x2...xn".
#
#
# - "x1, x2...xn" are called the independent variables and "y" is called the dependent variable.
#
#
# - Recall that simple linear regression is a statistical mode that examines linear relationship between two variables only.
#
#
# - In multiple linear regression, each independent variable has its own corresponding coefficient.
#
#
#        ŷ = B0 + B1*x1 + B2*x2 + B3*x3....+ Bn*xn
#
#
# Where,
#
#    - ŷ — ŷ is known as the predicted value of the dependent variable.
#    - B0 — represents the y-intercept (where the line crosses the y axis)
#    - B1,B2,B3...Bn — represents the coefficients of the input variables ‘X1, x2, x3...xn’. These values determines the level of influence ‘X1, x2, x3...xn’ has upon ‘y’.
#    - ‘X1, x2, x3...xn’ — represents the input variables, also known as the independent variables.

# %% [markdown]
# ---------------------------------------------------

# %% [markdown]
# ## Assumptions of Linear Regression :
# <b> Below are some important assumptions of Linear Regression. These are some formal checks while building a Linear Regression model, which ensures to get the best possible result from the given dataset :
#
#    1. Linear Relationship
#    2. Normal Distribution of Residuals
#    3. Multicollinearity
#    4. Autocorrelation or Variables Significance (Independence of Errors)
#    5. Homoscedasticity (Equal Variance of Errors)

# %% [markdown]
# ### 1. Linear Relationship :
# Linear regression needs the relationship between the independent and dependent variables to be linear. Let's use a scatter plot to check the relation of observed values (y_test) Vs fitted values (test_prediction) or a plot of residuals versus predicted values, which are a part of standard regression output.
#
#
# <b> What to do if this assumption is violated :
#
# - **Option - 1 :** Apply a nonlinear transformation to the independent and/or dependent variable. Common examples include taking the log, the square root, or the reciprocal of the independent and/or dependent variable.
#
#
# - **Option - 2 :** Add another independent variable to the model. For example, if the plot of x vs. y has a parabolic shape then it might make sense to add X2 as an additional independent variable in the model.

# %% [markdown]
# ### 2. Normal Distribution of Residuals :
# The residuals of the model are normally distributed. There are two common ways to check if this assumption is met :
#
#    1. Check the assumption visually using Q-Q plots or distribution (histohram) plot on the residuals.
#    2. Check the normality assumption using formal statistical tests like Shapiro-test, skew().
#
#
#
# <b> What to do if this assumption is violated :
#
# - **Option - 1 :** First, verify that any outliers aren’t having a huge impact on the distribution. If there are outliers present, make sure that they are real values and that they aren’t data entry errors.
#
#
# - **Option - 2 :** Next, you can apply a nonlinear transformation to the independent and/or dependent variable. Common examples include taking the log, the square root, or the reciprocal of the independent and/or dependent variable.

# %% [markdown]
# ## 3. Multicollinearity :
# The next assumption of linear regression is that there should be less or no multicollinearity in the given dataset.
#
#
# Multicollinearity happens when the independent variables are highly correlated with each other.
#
#
# In a model having correlated variables (Multicollinearity), it becomes difficult to determine which variable is contributing to predict the target variable. Another thing is, the standard errors tend to increase due to the presence of correlated variables.
#
#
# If we drop one correlated variable from the model, its predicted regression coefficients will change.  It can lead to wrong conclusions and poor performance of our model.
#
#
# We can test multicollinearity by using the following approaches :
#
#     a) Correlation Matrix
#     b) Tolerance
#     c) Variance Inflation Factor
#
#
# **a) Correlation Matrix :** Correlation represents the changes between the two variables. While calculating Pearson’s Bivariate Correlation matrix, it is recommended that the correlation coefficient among all independent variables should be less than 1.
#
#
# **b) Tolerance :** Tolerance helps us to determine the effect of one independent variable on all other independent variables.
#
#
# - Mathematically, it can be defined as T = 1-R², where R2 is computed by regressing the independent variable of concern onto the remaining independent variables. If the value of T is less than 0.01, i.e., T<0.01, then your data has multicollinearity.
#
#
# **c) Variance Inflation Factor (VIF) :** Variance Inflation Factor (VIF) is used to detect the presence of multicollinearity. Variance inflation factors (VIF) measure how much the variance of the estimated regression coefficients are inflated as compared to when the predictor variables are not linearly related.
#
#
# It is obtained by regressing each independent variable, say X on the remaining independent variables (say Y and Z) and checking how much of it (of X) is explained by these variables.
#
#
# VIF approach chooses each feature and regresses it against the remaining features. It is calculated by using the given formula :
#
#     VIF = 1 / 1 - R^2
#
#
# - If VIF value <=4, it implies no multicollinearity.
# - If VIF value>=10, it implies significant multicollinearity
#
#
# <b> What to do if this assumption is violated :
#
# - **Option - 1 :** You can drop one of those features which are highly correlated in the given data.
#
#
# - **Option - 2 :** Derive a new feature from collinear features and drop these features (used for making new features).

# %% [markdown]
# ### 4. Autocorrelation or Variables Significance (Independence of Errors) :
# Autocorrelation means a single column data values are related to each other. In other words f(x+1)is dependent on value of f(x). This phenomenon occurs when residuals or error terms are not independent of each other. Autocorrelation can be tested with scatter plots and It can also be checked using the Durbin-Watson test. Durbin-Watson test statistics can be implemented using statsmodels.durbin_watson() method.
#
#    - If the value of durbin_watson  = 2, it implies no autocorrelation
#    - If the value of durbin_watson lies between  0 and 2, it implies positive autocorrelation.
#    - If the value of durbin_watson lies between  2 and 4, it implies negative autocorrelation.
#
#
# It can also be checked this based on Ordinary Least Squares (OLS) Using StatsModels by using statsmodels.formula.api.ols() method.
#
# - P>|t| is the P-value for the null hypothesis that the coefficient is equal to zero. If the value is less than the confidence level, usually 0.05, it means that the null hypothesis can be rejected and there is a significant relationship between the coefficient value and the parameter.
#
#
# The residuals are independent. In particular, there is no correlation between consecutive residuals in time series data. For example, residuals shouldn’t steadily grow larger as time goes on.
#
#
# <b> What to do if this assumption is violated :
#
# - **Option - 1 :** Include the dummy variables in the data.
#
# - **Option - 2 :** Predicted Generalized Least Squares.
#
# - **Option - 3 :** Include a linear sequence,  if the residuals showing a consistent increment  or decrement in pattern.

# %% [markdown]
# ## 5. Homoscedasticity (Equal Variance of Errors) :
# The residuals have constant variance at every level of x. In other words residuals are equal across regression line.
#
#
# The residuals should have constant variance. If this condition is not followed, it is known as heteroscedasticity. Heteroscedasticity leads to the unbalanced scatter of residuals or error terms. Generally, non-constant variation arises in the presence of outliers.
#
#
# Heteroscedasticity increases the variance of the regression coefficient estimates, but the regression model doesn’t pick up on this. This makes it much more likely for a regression model to declare that a term in the model is statistically significant, when in fact it is not.
#
#
# Homoscedasticity can also be tested using scatter plot on fitted value vs. residual. The plot will show a funnel-shaped or “cone” pattern if heteroscedasticity exists.
#
#
# <b> What to do if this assumption is violated :
# There are three common ways to fix heteroscedasticity :
#
# - **Option - 1 :** Transform the dependent variable. One common transformation is to simply take the log of the dependent variable. If we are using independent variables(input features) to predict the number of cosmetic shops in a city (target variable). We may try to use input features to predict the log of the number of cosmetic shops in a city. Using the log of the target variable helps to reduce the heteroskedasticity.
#
#
# - **Option - 2 :** Redefine the dependent variable.  One common way to redefine the dependent variable is to use a rate, rather than the raw value.
#
#
# - **Option - 3 :** Use weighted regression. Another way to fix heteroscedasticity is to use weighted regression. This type of regression assigns a weight to each data point based on the variance of its fitted value. Essentially, this gives small weights to data points that have higher variances, which shrinks their squared residuals. When the proper weights are used, this can eliminate the problem of heteroscedasticity.

# %% [markdown]
# ## Influence plots :
# - a set of techniques that allows one to determine the degree to which specific data points affect the overall
# result of a statistical procedure. For example, in regression analysis it is used to examine which observations
# have a disproportionate influence on the proposed regression equation.
#
#
# - We can use influence plots to identify observations in our independent variables which have “unusual” values in comparison to other values.
#
#
# - Influence plots show the (externally) studentized residuals vs. the leverage of each observation.
#
#
# - Dividing a statistic (residuals) by a sample standard deviation is called **"studentizing"**.
#
#     studentizing = Residual/standard deviation of residuals
#
#
# - **Leverage** is a measure of how far away the independent variable values of an observation are from those of the other observations. High-leverage points are outliers with respect to the independent variables.
#
#
# - Influence plots are used to identify influential data points. They depend on both the residual and leverage i.e they take itnto account both the x value and y value of the observation.
#
#
# - In statsmodels .influence_plot the influence of each point can be visualized by the criterion keyword argument. Options are Cook’s distance and DFFITS, two measures of influence. Steps to compute Cook’s distance :
#
#     1. Delete observations one at a time.
#     2. Refit the regression model on remaining (n−1) observations
#     3. Examine how much all of the fitted values change when the ith observation is deleted.
#
#
# <b> Steps to plot the Influence plot :
#
# import statsmodels.api as sm
#
# sm.graphics.influence_plot(lm, criterion="cooks")
#
#
# ![image-2.png](attachment:image-2.png)
#
#
# <b> To identify values with high influence, we look for observations with :
#
#    1. Big blue points (high Cook’s distance) and
#    2. High leverage (X-axis) which additionally have
#    3. High or low studentized residuals (Y-axis).
#
#
# There are a few worrisome observations with big blue dots in the plot:
#
#    - RR.engineer has large leverage but small residual.
#    - Both contractor and reporter have low leverage but a large residual.
#    - Conductor and minister have both high leverage and large residuals, and, therefore, large influence.

# %% [markdown]
# <b> What is the difference between outliers and influential points ?
#
# An outlier is a point with a large residual. An influential point is a point that has a large impact on the regression.
# Surprisingly, these are not the same thing. A point can be an outlier without being influential.

# %% [markdown]
# ## Added Variable Plots or Partial Regression Plots (AV Plot) :
# - Investigate the relationship between a dependent and independent variables conditional on other independent varibales.
#
#
# - Identify the effects of the individual data values on the estimation of a coefficient.
#
#
# - Investigate violations of underlying assumptions such as linearity and homoscedasticity.
#
#
# - In a partial regression plot, to discern the relationship between the response variable and the kth variable, we compute the residuals by regressing the response variable versus the independent variables excluding Xk. We can denote this by X~ k.
# We then compute the residuals by regressing Xk on X~k. The partial regression plot is the plot of the former versus the latter residuals.
#
#
# - Plot partial regression for a set of regressors, for a quick check of all the regressors, we can use plot_partregress_grid from statsmodels.api library.

# %% [markdown]
# <b> Steps to plot the Influence plot :
#
# import statsmodels.api as sm
#
# sm.graphics.plot_partregress_grid(lm)
#
#
# ![image.png](attachment:image.png)
#
#
# From the above Partial Regression Plots (AV Plot), We observe a positive relationship between sales and TV as well as between sales and radio, the relationship seems to be linear in both cases. But the relationship between sales and newspaper not showing any significance.
