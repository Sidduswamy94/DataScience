# %% [markdown]
# # <p style='text-align: center;'> Time Series Modelling </p>

# %% [markdown]
# ## Time Series:
# - A **Time Series** is a sequence of observations recorded over a certain period of time. In other words **Time Series** can be defined as a set of measurements of certain variable made at **regular time imtervals**.
#
#
# - A simple example of time series is how we come across different temperature changes day by day or in a month.
#
#
# - Here Time acts as an independent variable for estimation.
#
#
# - **Timeseries forecasting** in simple words means to forecast or to predict the future value(eg-stock price) over a period of time. There are different approaches to predict the value, consider an example there is a company XYZ records the website traffic in each hour and now wants to forecast the total traffic of the coming hour. If I ask you what will your approach to forecasting the upcoming hour traffic?
#
# ![image.png](attachment:image.png)
#
#
# - A different person can have a different perspective like one can say find the mean of all observations, one can have like take mean of recent two observations, one can say like give more weightage to current observation and less to past, or one can say use interpolation. There are different methods to forecast the values.

# %% [markdown]
# ## Time Series Pattern Types
# <b> There are multiple Pattern Types in Time Series data, as follows:

# %% [markdown]
# ### 1. Trend:
# - A **trend** is a long-term increase or decrease in time series data.
#
#
# - One simple way of determining the trend is to calculate a running average over the series.
#
#
# - Examples of time series that have a clear trend are **Smartphone sales for a 3 year period (Uptrend)** and the **stock market price for a wall street company (Downtrend)**. The graphs as shown below:
#
# ![image.png](attachment:image.png)
#
#
# - <b> Trends can be:
#
#     - additive
#
#     - multiplicative
#
#
# - An **additive trend** corresponds to a changing mean.
#
#
# - A **multiplicative trend** corresponds to changing mean and variance.

# %% [markdown]
# ### 2. Seasonality:
# - **Seasonality** is a simple term that means while predicting a time series data there are some months in a particular domain where the output value is at a peak as compared to other months. for example if you observe the data of tours and travels companies of past 3 years then you can see that in November and December the distribution will be very high due to holiday season and festival season. So while forecasting time series data we need to capture this seasonality.
#
#
# - Seasonality is always of a fixed and known frequency.

# %% [markdown]
# ### 3. Cyclic:
# - A **cycle** occurs when the data exhibit rises and falls that are not of a fixed frequency. These fluctuations are usually due to economic conditions, and are often related to the “business cycle”.
#
#
# - The duration of these fluctuations is usually at least 2 years.
#
#
# <b> Difference between Seasonality Vs Cyclic:
#
# - Many people confuse cyclic behaviour with seasonal behaviour, but they are really quite different. If the fluctuations are not of a fixed frequency then they are cyclic; if the frequency is unchanging and associated with some aspect of the calendar, then the pattern is seasonal. In general, the average length of cycles is longer than the length of a seasonal pattern, and the magnitudes of cycles tend to be more variable than the magnitudes of seasonal patterns.
#
#
# - Many time series include trend, cycles and seasonality. When choosing a forecasting method, we will first need to identify the time series patterns in the data, and then choose a method that is able to capture the patterns properly.
#
#
# - The examples in below Figure shows different combinations of the above components.
#
# ![image.png](attachment:image.png)
#
#
# - The above Figure Four examples of time series showing different patterns. Thay are as:
#
#
#    1. The monthly housing sales (top left) show strong seasonality within each year, as well as some strong cyclic behaviour with a period of about 6–10 years. There is no apparent trend in the data over this period.
#
#
#    2. The US treasury bill contracts (top right) show results from the Chicago market for 100 consecutive trading days in 1981. Here there is no seasonality, but an obvious downward trend. Possibly, if we had a much longer series, we would see that this downward trend is actually part of a long cycle, but when viewed over only 100 days it appears to be a trend.
#
#
#    3. The Australian quarterly electricity production (bottom left) shows a strong increasing trend, with strong seasonality. There is no evidence of any cyclic behaviour here.
#
#
#    4. The daily change in the Google closing stock price (bottom right) has no trend, seasonality or cyclic behaviour. There are random fluctuations which do not appear to be very predictable, and no strong patterns that would help with developing a forecasting model.

# %% [markdown]
# ### 4. Irregular or Unexpected Events:
# - **Unexpected events** mean some dynamic changes occur in an organization, or in the market which cannot be captured.
#
#
# - They are often of short duration and non-repeating.
#
#
# - For example a current pandemic we are suffering from, and if you observe the Sensex or nifty chart there is a huge decrease in stock price which is an unexpected event that occurs in the surrounding.
#
#
# - Methods and algorithms are using which we can capture seasonality and trend But the unexpected event occurs dynamically so capturing this becomes very difficult.
#
#
# - The below graph shows the Irregular or Unexpected Events occurs in stock price:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5. White noise:
# - A **white noise** series is one with a zero mean, a constant variance, and no correlation between its values at different times.
#
#
# - Time series that show no autocorrelation are called **white noise**.
#
#
# - Bolow Figure gives an example of a white noise series:
#
# ![image.png](attachment:image.png)
#
#
# - From the above figure, Since values are uncorrelated, the adjacent values do not help to forecast or predict future values.
#
#
# - **Example:** Stock prices of companies may vary daily and time series become uncorrelated.

# %% [markdown]
# ### 6. Stationarity:
# - A time series whose statistical properties, such as mean, variance, etc., remain constant over time, are called a **stationary** time series.
#
#
# - In other words, a stationary time series is a series whose statistical properties are independent of the point in time at which they are observed. A stationary time series has a constant variance and it always returns to the long-run mean.
#
#
# - Below graph shows the stationary time series:
#
# ![image-3.png](attachment:image-3.png)
#
#
# - A time series whose statistical properties change over time is called a **non-stationary** time series. Thus a time series with a trend or seasonality is non-stationary in nature. This is because the presence of trend or seasonality will affect the mean, variance and other properties at any given point in time.
#
#
# - Below graph shows the non-stationary time series:
#
# ![image-4.png](attachment:image-4.png)
#
#
# - The time series should be stationary to build the model.
#
#
# <b> Why is stationarity one of the key components in time series analysis?
#
# -  The inferences drawn from a non-stationary process will not be reliable as its statistical properties will keep on changing with time. While performing analysis, you would typically be interested in the expected value of the mean, the variance, etc. But if these parameters are continuously changing, estimating them by averaging over time will not be accurate. Hence, stationary data are easier to analyse and any forecast made using a non-stationary data would be erroneous and misleading. Because of this, many statistical procedures applied in time series analysis makes an assumption that the underlying time series data is stationary. This assumption is necessary because most time series forecasting methods predict the statistical properties of the time series will remain the same in the future as they have been in the past.
#
#
# <b> Difference between stationarity Vs non-stationarity:
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ### How to check/detect the Stationarity?
#
# - Since many analytical tools and statistical tests assume the time series to be stationary, it is very important to ascertain whether a given series is generated by a stationary process. Below are certain ways to do the same.
#
#    a. Rolling Statistics (Visualization)
#
#    b. Dickey Fuller Test - DFT (Statistical Tests)

# %% [markdown]
# ### a. Rolling Statistics (Visualization):
# - The most common method to check whether a given data comes from a stationary series or not is by simply plotting the data or some function of it.
#
#
# - Plot the moving average (mean) or moving variance (std) to check the if it is varies with time.
#
#
# - In other words, A rolling analysis of a time series model is often used to assess the model's stability over time.
#
#
# - Below graph shows whether data is stationary or non-stationary time series:
#
# ![image.png](attachment:image.png)
#
#
# - From the above figure, we can see that the mean and variance **increase** constantly.

# %% [markdown]
# ### b. Dickey Fuller Test - DFT (Statistical Tests):
# - **Augmented Dickey-Fuller Test** - The Augmented Dickey-Fuller test is one of the most popular tests to check for stationarity. It tests the below hypothesis.
#
#
#    - Null Hypothesis, H0: The time series is not stationary.
#
#
#    - Alternative Hypothesis, H1: The time series is stationary.
#
#
# - We can use the **adfuller** method from the statsmodels library to perform this test in Python and compare the value of the test statistics or the p-value.
#
#
# - If the p-value is less than or equal to 0.05 or the absolute value of the test statistics is greater than the critical value, you reject H0 and conclude that the time series is stationary.
#
#
# - If the p-value is greater than 0.05 or the absolute value of the test statistics is less than the critical value, you fail to reject H0 and conclude that the time series is not stationary.

# %% [markdown]
# ### Transforming/Removal a Non-Stationary Series into a Stationary Series:
# - <b> Getting a Time Series perfectly stationary is desirable but not practicle, so it is made as close as possible using these statistical tests. They are:
#
#    a. Differencing
#
#    b. Decomposition

# %% [markdown]
# ### a. Differencing:
# - **Differencing** is performed by substracting the previous observation from the current observation.
#
#
#     Δyt = (yt) – (yt-1)
#
#
# - Where,
#
#     'Δyt' is the difference between two successive values.
#
#     'yt' is the value of y at t and 'yt-1' is the value preceding yt.
#
#
# - Below figures shows the Transforming/Removal a Non-Stationary Series into a Stationary Series by using Differencing:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### b. Decomposition:
# - De-trending or de-seasonalizing eliminates the trend and seasonality respectively.
#
#
# - Decomposition is performed on the original series by regressing the series on time and taking the residuals from the regression.
#
#
#     xt = Tt + St + Rt
#
#
# - Where,
#
#     Tt is Trend
#
#     St is Seasonality
#
#     Rt is Residuals
#
#
# - The residuals are what is left of the original signal after we remove the trend and the seasonality.
#
#
#
# - Below figures shows the Transforming/Removal a Non-Stationary Series into a Stationary Series by using Decomposition:
#
# ![image.png](attachment:image.png)
#
#
# **Note:** We can also use techniques like **transformation** which penalize higher values more than lower values. Example: square root, cube root, log, etc.

# %% [markdown]
# ### 7. Autocorrelation (ACF) and Partial Autocorrelation (PACF):
#
# ### i. Autocorrelation (ACF)
# - The **autocorrelation function (ACF)** is a statistical technique that we can use to identify how correlated the values in a time series are with each other.
#
#
# - The ACF plots the correlation coefficient against the lag, which is measured in terms of a number of periods or units. A lag corresponds to a certain point in time after which we observe the first value in the time series.
#
#
# - The correlation coefficient can range from -1 (a perfect negative relationship) to +1 (a perfect positive relationship). A coefficient of 0 means that there is no relationship between the variables. Also, most often, it is measured either by Pearson’s correlation coefficient or by Spearman’s rank correlation coefficient.
#
#
# - ACF will identify the order of MA process.
#
#
# - Below, we can see an example of the ACF plot:
#
# ![image-2.png](attachment:image-2.png)
#
#
# - The above validates the assumption that how the consumption is correlated to the previous 12 lags and next 12 lags consumption and so on. The relation inside the shaded area is something that is statistically irrelevant.

# %% [markdown]
# ### b. Partial Autocorrelation (PACF)
# - Partial autocorrelation is a statistical measure that captures the correlation between two variables after controlling for the effects of other variables.
#
#
# - PACF is similar to ACF, but the intermediate lags between t and t-p are removed, that is, correlation between X(t) and X(t-p) with p-1 lags excluded.
#
#
# - PACF will identify the order of AR process.
#
#
# - For example, if we’re regressing a signal S at lag t (St) with the same signal at lags t-1, t-2 and t-3 (S(t-1), S(t-2), S(t-3)), the partial correlation between St and S(t-3) is the amount of correlation between St and S(t-3) that isn’t explained by their mutual correlations with S(t-1) and S(t-2). That being said, the way of finding PACF between St and S(t-3) is to use regression model.
#
#
#     St = ϕ1 S(t-1) + ϕ2 S(t-2) + ϕ3 S(t-3) + E
#
#
# - Where,
#
#     - ϕ1, ϕ2 and ϕ3 are coefficients.
#
#     - E  is error.
#
#
# - Below, we can see an example of the PACF plot:
#
# ![image.png](attachment:image.png)
#
#
# - From the above PACF plot if you observe the values at regular intervals, at the 12th lag it is correlated to 0th lag and for 24 lag correlation further decreases and further, it is getting weaker and weaker.
#
#
# <b> Note: ACF and PACF are used to determine the value of p and q. Where p is the order of the AR term and q is the order of the MA term.
#
#
# ### Characteristics of ACF and PACF:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# --------------------------------

# %% [markdown]
# ## <p style='text-align: center;'> Time Series Models </p>

# %% [markdown]
# ### Time Series Models:
# <b> Time series models are used to forecast events based on verified historical data. Common types include AR model, MA model, ARMA model, ARIMA model and SARIMA model. Not all models will yield the same results for the same dataset, so it’s critical to determine which one works best based on the individual time series. Let's discuss one by one:

# %% [markdown]
# ### 1. Auto-Regressive (AR) Model:
# - In an AR model, we predict future values based on a weighted sum of past values.
#
#
# - In other words, A statistical model is autoregressive if it predicts future values based on past values.
#
#
# - For example, an autoregressive model might seek to predict a stock's future prices based on its past performance.
#
#
# - It’s a linear model, where current period values are a sum of past outcomes multiplied by a numeric factor. We denote it as AR(p), where “p” is called the order of the model and represents the number of lagged values we want to include.
#
#
# - For instance, if we take X as time-series variable, then an AR(2), also known as a autoregressive model, would look something like this:
#
#
#     Xt = C + ϕ1 Xt-1 + ϕ2 Xt-2 + Et
#
#
# - Where,
#
#     - Xt is the function of different past values of the same variable.
#
#     - Xt-1 represents the value of X during the previous period.
#
#     - Xt-2 represents the value of Xt-1 during the previous period.
#
#     - ϕ1 and ϕ2 associated coefficients (parameters).  It’s good to note that these coefficients should always be between -1 and 1.
#
#     - Et is residual (represents the difference between our prediction for period t and the correct value (ϵt = yt - ŷt)).
#
#     - C is constant
#
#
# - AR(1) is a model whose current value is based on the preceding value. AR(2) is based on the preceding two values.
#
#
# - Below figure is an example of AR models:
#
# ![image.png](attachment:image.png)
#
#
# **Note:** The AR model assumes that the current value ( Xt ) is dependent on previous values ( Xt−1, Xt−2, Xt−3,...). Because of this assumption, we can build a **linear regression model**. To figure out the order of an AR model, we would use the PACF.

# %% [markdown]
# ### 2. Moving Average (MA) Model:
# - MA model is used to forecast or predict time series if Xt depends only on the random error terms.
#
#
# - The MA model assumes that the current value ( Xt ) is dependent on the error terms including the current error (ϵt,ϵt−1,ϵt−2,ϵt−3,...). Because error terms are random, there is no linear relationship between the current value and the error terms.
#
#
# - To figure out the order of an MA model, you would use the ACF.
#
#
# - The equation for the MA model is:
#
#     Xt = µ + ϕ1 Et-1 + ϕ2 Et-2 + ... + ϕp Et-p
#
#
# - Where,
#
#     - Xt is the function of different past errors terms.
#
#     - Et is residual (represents the difference between our prediction for period t and the correct value (ϵt = yt - ŷt)).
#
#     - ϕ1, ϕ1 and ϕp associated coefficients (parameters).  It’s good to note that these coefficients should always be between -1 and 1.
#
#     - µ is the mean of the series.
#
#
# - Below figure is an example of MA models:
#
# ![image.png](attachment:image.png)
#
#
# <b> How do I choose between AR and MA model?
#
# - The primary difference between an AR and MA model is based on the correlation between time series objects at different time points. The covariance between x(t) and x(t-n) is **zero** for MA models. However, the correlation of x(t) and x(t-n) gradually declines with n becoming **larger** in the AR model.
#
#
# - A Moving Average model is similar to an Autoregressive model, except that instead of being a linear combination of past time series values, it is a linear combination of the past white noise terms.

# %% [markdown]
# ### 3. Auto-Regressive and Moving Average (ARMA) Model:
# - ARMA model is used to forecast or predict time series using both the past values and the error terms.
#
#
# - A useful class of models is obtained when AR and MA terms are added together in a single expression. A time series
# {xt} follows an autoregressive moving average (ARMA) process of order (p, q), denoted ARMA (p, q), when te equation for the ARMA model is:
#
#     Xt = (C + ϕ1 Xt-1 + ϕ2 Xt-2 + Et) + (µ + ϕ1 Et-1 + ϕ2 Et-2 + ... + ϕp Et-p)
#
#
# - It is the combination of AR and MA model.
#
#
# - It is referred as ARMA(p, q), where p is autoregressive terms and q is moving average terms.
#
#
# - ARMA is the combination of the AR and MA models. ARMA models cover both aspects of AR and MA. The ARMA model predicts the future values based on both the previous values and errors. Thus ARMA has better performance than AR and MA models alone.

# %% [markdown]
# ### 4. Auto-Regressive Integrated Moving Average (ARIMA) Model:
# - ARIMA model predicts a value in a response time series as a linear combination of its own past values, past errors, also current and past values of other time series.
#
#
# - ARIMA models are generally denoted as ARIMA (p,d,q) where p is the order of autoregressive model, d is the degree of differencing, and q is the order of moving-average model.
#
#
# - ARIMA models use differencing to convert a non-stationary time series into a stationary one, and then predict future values from historical data.
#
#
# - An ARIMA model is characterized by 3 terms: p, d, q
#
#
# - where,
#
#     p is the order of the AR term.
#
#     q is the order of the MA term.
#
#     d is the number of differencing required to make the time series stationary.
#
#
# - <b> An ARIMA model can be understood by outlining each of its components as follows:
#
#    - **Autoregression (AR):** A statistical model is autoregressive if it predicts future values based on past values.
#
#    - **Integrated (I):** represents the differencing of raw observations to allow the time series to become stationary (i.e., data values are replaced by the difference between the data values and the previous values).
#
#    - **Moving average (MA):** MA model is used to forecast or predict time series if Xt depends only on the random error terms, a moving average model applied to lagged observations.
#
#
# - **Note:** If no difference is done (d = 0), the models are usually referred to as ARMA (p, q)  models.
#
#
# <b> Why use ARIMA over ARMA?
#
# - The difference between ARMA and ARIMA is the integration part. The integrated I stands for the number of times differencing is needed to make the times series stationary. ARIMA models are widely used for real life time series analysis since most times series data are non stationary and need differencing.
#
#
# <b> What’s Wrong with ARIMA?
#
# - A problem with ARIMA is that it does not support **seasonal data**. That is a time series with a repeating **cycle**.
#
#
# - ARIMA expects data that is either not seasonal or has the seasonal component removed, e.g. seasonally adjusted via methods such as seasonal differencing.

# %% [markdown]
# ### 5. Seasonal Auto-Regressive Integrated Moving Average (SARIMA) Model:
# - Seasonal Autoregressive Integrated Moving Average, SARIMA or Seasonal ARIMA, is an extension of ARIMA that explicitly supports univariate time series data with a seasonal component.
#
#
# - It adds three new hyperparameters to specify the **autoregression (AR)**, **differencing (I)** and **moving average (MA)** for the **seasonal** component of the series, as well as an additional parameter for the period of the seasonality.
#
#
# - The Autoregressive (AR), Integrated (I), and Moving Average (MA) parts of the model remain as that of ARIMA. The addition of Seasonality adds robustness to the SARIMA model. It’s represented as:
#
# ![image-2.png](attachment:image-2.png)
#
#
# - where
#
#    - p: Trend autoregression order.
#    - d: Trend difference order.
#    - q: Trend moving average order.
#    - P: Seasonal autoregressive order.
#    - D: Seasonal difference order.
#    - Q: Seasonal moving average order.
#    - m: The number of time steps for a single seasonal period.
#
#
# Similar to ARIMA, the P,D,Q values for seasonal parts of the model can be deduced from the ACF and PACF plots of the data.

# %% [markdown]
# ----------------------------------------

# %% [markdown]
# ### Steps in Time Series Forecasting for ARIMA Model:
# - **Step-1:** Visualize the time series - check for trend, seasonality, or random patterns.
#
#
# - **Step-2:** Stationaries the series using decomposition or differencing techniques.
#
#
# - **Step-3:** Plot ACF/PACF and find (p, d, q) parameters.
#
#
# - **Step-4:** Build a ARIMA Model.
#
#
# - **Step-5:** Evaluate and Make prediction using final ARIMA model.

# %% [markdown]
# ----------------------------

# %% [markdown]
# ### Applications of Time Series Forecasting
# - Daily sales score of E-commerce.
#
#
# - Yearly GDP of a developing country.
#
#
# - Weekly production of a shoe manufacturing company.
#
#
# - Monthly tickets sold by an airline.
