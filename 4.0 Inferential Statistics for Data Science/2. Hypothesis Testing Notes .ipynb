# %% [markdown]
# # <p style='text-align: center;'> Hypothesis Testing </p>

# %% [markdown]
# ## Hypothesis Testing :
# - Hypothesis Testing can be used to determine whether a statement about the value of a population parameter should or should not be rejected.
#
#
# - Hypothesis Testing refers to making an assumptions, about a population parameter based on sample parameter is called Hypothesis Testing.
#
#
# - Collecting Sample Data, calculating a sample statistics. Using a sample statistic to evaluate the hypothesis (how likely is
#   it that our hypothesized parameter is correct. To Test the validity of our assumption we determine the difference between the
#   hypothesized parameter value and the sample value.
#
#
# - There are two types of hypothesis testing in statistics. They are :
#
#         1. Null Hypothesis (Ho)
#         2. Alternate Hypothesis (Ha or H1)
#
#
#
# ## Null Hypothesis and Alternate Hypothesis :
# - The Null Hypothesis is the assumption that the event will not occur. A null hypothesis has no bearing on the study's outcome unless it is rejected.
#
#
# - H0 is the symbol for it, and it is pronounced H-naught.
#
#
# - The Alternate Hypothesis is the logical opposite of the null hypothesis. The acceptance of the alternative hypothesis follows the rejection of the null hypothesis.
#
#
# - H1 or Ha is the symbol for it, and it is pronounced alternative hypothesis.
#
#
# - Whereas Null Hypothesis refers to status quo / no action / no difference and Alternative Hypothesis refers to research / action / difference.

# %% [markdown]
# ## Developing Null Hypothesis and Alternate Hypothesis :
# - It is not always obvious how the null and alternative hypothesis should be formulated.
#
#
# - Care must be taken to structure the hypothesis appropriately so that the test conclusion provides the information the resercher wants.
#
#
# - The context of the situation is very important in determining how the hypothesis should be stated.
#
#
# - In some cases it is easier to identify the alternative hypothesis first. In other cases the null is easier.
#
#
# - Correct hypothesis formulation will take practice.
#
#
# ## Alternative Hypothesis as a Research Hypothesis :
# - Many applications of Hypothesis Testing involve an attempt to gather evidence in support of a researsh hypothesis.
#
#
# - In such cases, it is often best to begin with the alternative hypothesis and make it the conclusion that the researcher hopes to support.
#
#
# - The conclusion that the research hypothesis is true is made if the sample data provide sufficient evidence to show that the null hypothesis can be rejected.
#
#
# -

# %% [markdown]
# ## Examples for Alternative Hypothesis as a Research Hypothesis :

# %% [markdown]
# <b> Example - 1 : A new manufacturing method is believed to be better than the current method.
#
#
# - Alternative Hypothesis :
#
#
#     - The new manufacturing method is better.
#
#
# - Null Hypothesis :
#
#
#     - The new manufacturing method is not better than the old method.

# %% [markdown]
# <b> Example - 2 : A new bonus plan, that is developed in an attempt to increase sales.
#
#
# - Alternative Hypothesis :
#
#
#     - The new bonus plan increase sales.
#
#
# - Null Hypothesis :
#
#
#     - The new bonus plan does not increase sales.

# %% [markdown]
# <b> Example - 3 : A new drug is developed with a goal of lowering Cholesterol-level more than the existing drug.
#
#
# - Alternative Hypothesis :
#
#
#     - The new drug lowers Cholesterol-level more than the existing drug.
#
#
# - Null Hypothesis :
#
#
#     - The new drug does not lowers Cholesterol-level more than the existing drug.

# %% [markdown]
# ## Null Hypothesis as an Assumption to be challenged :

# %% [markdown]
# <b> Example : The label on a milk bottle states that it contains 1000 ml.
#
#
# - Null Hypothesis :
#
#
#     - The label is correct. µ ≥ 1000 ml.
#
#
# - Alternative Hypothesis :
#
#
#     - The label is incorrect. µ < 1000 ml.

# %% [markdown]
# ## Nul and Alternative Hypothesis about a Population Mean µ :
# - The equality part of the hypothesis always appearsin the null hypothesis.
#
#
# - In general, a hypothesis test about the value of a population mean µ must take on of the following three forms (where µo is the hypothesized value of the population mean).
#
#
#
#             Ho:µ ≥ µo             Ho:µ ≤ µo              Ho:µ = µo
#             H1:µ < µo             H1:µ > µo              Ho:µ ≠ µo
#
#             One-tailed            One-tailed             Two-tailed
#            (lower-tail)          (upper-tail)

# %% [markdown]
# ### One-tailed Tests :
# - A one-tailed test may be either left-tailed (lower-tail) or right-tailed (upper-tail).
#
#
# - A left-tailed test is used when the alternative hypothesis states that the true value of the parameter specified in the null hypothesis is less than the null hypothesis claims.
#
#
# - A right-tailed test is used when the alternative hypothesis states that the true value of the parameter specified in the null hypothesis is greater than the null hypothesis claims.
#
#
# ### Two-tailed Tests :
# - The main difference between one-tailed and two-tailed tests is that one-tailed tests will only have one critical region
#   whereas two-tailed tests will have two critical regions. If we require a 100(1 − α)% confidence interval we have to make some
#   adjustments when using a two-tailed test.
#
#
# - The confidence interval must remain a constant size, so if we are performing a two-tailed test, as there are twice as many
#   critical regions then these critical regions must be half the size. This means that when we read the tables, when performing
#   a two-tailed test, we need to consider α/2 rather than α.

# %% [markdown]
# <b> Example :

# %% [markdown]
# - A major hospital in Chennai provides one of the most comprehensive emergency medical services in the world. Operating in a
#   multiple hospital system with approximately 10 mobile medical units, the service goal is to respond to medical emergencies
#   with a mean time of 8 minutes or less. The director of medical services wants to formulate a hypothesis test that could use a
#   sample of emergency response times to determine whether or not the service goal of 8 minutes or less is being achieved.
#
#
# <b> Solution :
# - Where : µ = mean response time for the population of medical emergency requests.
#
#
# - Ho: µ ≤ 8  ---> The emergency service is meeting the response goal, no follow-up action is necessary.
#
#
# - H1: µ > 8  ---> The emergency service is not meeting the response goal, appropriate follow-up action is necessary.
#
#
# - Here we have to use a one-tailed (right-tailed) test.

# %% [markdown]
# ### Level of significance :
# - It is a fixed probability of wrongly rejecting a True Null Hypothesis. Denoted by alpha or α.
#
#
# - For example, if α=5%, that means we are okay to take a 5% risk and conclude there exists a difference when there is no actual difference.
#
#
# ### Critical Value :
# - Denoted by C and it is a value in the distribution beyond which leads to the rejection of the Null Hypothesis. It is compared to the test statistic.
#
#
# ## p-value :
# - It is the proportion of samples (assuming the Null Hypothesis is true) that would be as extreme as the test statistic. It is denoted by the letter p.

# %% [markdown]
# ### Z-test (Z-Score):
# - Z-test is the statistical test, used to analyze whether two population means are different or not when the variances are known and the sample size is large.
#
#
# - This test statistic is assumed to have a normal distribution, and standard deviation must be known to perform an accurate z-test.
#
#
# - A z-statistic, or z-score, is a number representing the value’s relationship to the mean of a group of values, it is measured with population parameters such as population standard deviation and used to validate a hypothesis.
#
#
# - For example, the null hypothesis is “sample mean is the same as the population mean”, and alternative hypothesis is “the sample mean  is not the same as the population mean”.

# %% [markdown]
# ### T-test (T-Score) :
# - In order to know how significant the difference between two groups are, T-test is used, basically it tells that difference (measured in means) between two separate groups could have occurred by chance.
#
#
# - This test assumes to have a normal distribution while based on t-distribution, and population parameters such as mean, or standard deviation are unknown.
#
#
# - The ratio between the difference between two groups and the difference within the group is known as T-score. Greater is the t-score, more is the difference between groups, and smaller is the t-score, more similarities are there among groups.

# %% [markdown]
# ### T-test vs Z-test :
# <b> Comparing T-test and Z-test based on conditions, they are :
#
#
# <b> 1. Sample size :
# - As the sample size differs from analysis to analysis, a suitable test for hypothesis testing can be adopted for any sample size. For example, z-test is used for it when sample size is large, generally n >30.
#
#
# - Whereas t-test is used for hypothesis testing when sample size is small, usually n < 30 where n is used to quantify the sample size.
#
#
# <b> 2. Use :
# - The z-test is the parametric test, implemented to determine if the means of two different datasets are different from each other, when the standard deviation is known.
#
#
# - The t-test is the statistical test that can be deployed to measure and analyze whether the means of two different populations are different or not when the standard deviation is not known.
#
#
# <b> 3. Types of distribution :
# - Both t-test and z-test employ the different use of distribution to correlate values and make conclusions in terms of hypothesis testing. Notably, t-test is based on the Student’s t-distribution, and the z-test counts on Normal Distribution.
#
#
# <b> 4. Population Variance :
# - Implementing both tests in testing of hypothesis, population variance is significant in obtaining the t-score and z-score.
# While the population variance in the z-test is known, it is unknown in the t-test.
#
#
# <b> 5. Key Assumptions :
# - Some major assumptions are considered while conducting either t-test or z-test.
#
#
# - In a t-test,
#
#         - All data points are assumed to be not dependent.
#
#         - Samples values are taken and recorded accurately.
#
#         - Work on smaller sample size, n should not exceed thirty but also shouldn't be less than five.
#
#
#
# - In the z-test,
#
#         - All data points are independent,
#
#         - Sample size is assumed to be large, n should have exceeded thirty.
#
#         - Normal distribution for z with mean zero and variance as one.

# %% [markdown]
# ## Steps of Hypothesis testing :
# - Step 1 : Develop the Null and Alternative Hypotheses.
#
#
# - Step 2 : Specify the level of significance (α).
#
#
# - Step 3 : Collect the Sample data and calculate the Test Statistic.
#
#
# - Step 4 : Compute the p-value. Using the value of the test statistics.
#
#     - The p-value is the probability, computed using the test staitistics, that measures the support (or lack of support) provided by the sample for the null hypothesis.
#
#     - If the p-value is less than or equal to the level of significant α, the value of the test statistic is in the rejection region.
#
#
# - Step 5 : Reject Ho if the p-value ≤ α.
#
#      - p low Null go  <---> p ≤ α (Reject Ho)
#      - p high Null fly  <---> p > α (Accept Ho)

# %% [markdown]
# ### Examples on One-Tailed and two-Tailed About a Population Mean when the σ is known (Z-Test) :

# %% [markdown]
# ### Right-tailed test Example :
#
# 1. The mean response times for a random sample of 30 pizza deliveries is 32 minutes. The population standard deviation is believed  to be 10 minutes. The pizza delivery services director wants to perform a hypothesis test, with α =0.05 level of
# significance, to determine whether the service goal of 30 minutes or less is being achieved ?
#
#
# <b> Ans :
# - Here,
#
#     - Random sample (n)=30
#     - Sample mean (x̅)= 32
#     - Population mean (μ)=30
#     - Standard deviation (σ)=10
#     - level of significant (α)=0.05
#
#
# - Step 1 : Develop the Null and Alternative Hypotheses :
#
#             Ho: µ ≤ 30
#             H1: µ > 30
#
#
# - Step 2 : Specify the level of significance (α) :
#
#             α=0.05
#
#
# - Step 3 : Compute the value of the Test Statistic :
#
#                  x̅ - μ
#             Z = --------
#                  σ / √n
#
#                 32 - 30
#             Z = --------
#                 10 / √30
#
#
#             Z = 1.09
#
#
# - Step 4 : Compute the p-value.
#
#             For Z=1.09, p-value = 0.86214 ---> This is a right-tailed test, i.e. p-value = (1 - 0.86214) = 0.137
#
#
# - Step 5 : Determine whether to Reject Ho :
#
#     - Here p-value (p) is greater than level of significant (α), i.e. p-value (0.137) > α (0.05). We do not Reject Ho.
#
#
# <b> There are not sufficient evidence to infer that pizza delivery services is not meeting the response goal of 30 minutes.

# %% [markdown]
# ### Two-tailed test Example :
#
# 2. Assume that a sample of 30 milk cartoon provides a sample mean of 505 ml, the population standard deviation is believed to be 10 ml. Perform a hypothesis test, at the 0.03 level of significance, population mean 500 ml and to help determine whether the filling process should continue operating or be stopped and corrected ?
#
#
# <b> Ans :
# - Here,
#
#     - Random sample (n)=30
#     - Sample mean (x̅)= 505
#     - Population mean (μ)=500
#     - Standard deviation (σ)=10
#     - level of significant (α)=0.03
#
#
# - Step 1 : Develop the Null and Alternative Hypotheses :
#
#             Ho: µ = 500
#             H1: µ ≠ 500
#
#
# - Step 2 : Specify the level of significance (α) :
#
#             α=0.03
#
#
# - Step 3 : Compute the value of the Test Statistic :
#
#                  x̅ - μ
#             Z = --------
#                  σ / √n
#
#                 505 - 500
#             Z = ----------
#                 10 / √30
#
#
#             Z = 2.74
#
#
# - Step 4 : Compute the p-value.
#
#             For Z=2.74, p-value = 0.9969 --> This is a two-tailed test, i.e. p-value = 2(1 - 0.9969) = 0.0061
#
#
# - Step 5 : Determine whether to Reject Ho :
#
#     - Here p-value (p) is lesser than level of significant (α), i.e. p-value (0.0061) < α (0.03). We Reject Ho.
#
#
# <b> There is no sufficient statistical evidence to infer that the null hypothesis is true (i.e. the milk filling quantity is not 500 ml, So the filling process must be stopped and corrected).

# %% [markdown]
# ### Left-tailed test Example :
#
# 3. A machine is producing perfume bottles with the long term average of 150 ml and the standard deviation of 1.414 ml. Four bottles were picked and the average volume was found to be 149 ml. Has the average volume min of 150 ml ? Test with 95% confidence level.
#
#
# <b> Ans :
# - Here,
#
#     - Random sample (n)=4
#     - Sample mean (x̅)= 149
#     - Population mean (μ)=150
#     - Standard deviation (σ)=1.414
#     - level of significant (α)=0.05
#
#
# - Step 1 : Develop the Null and Alternative Hypotheses :
#
#             Ho: µ ≥ 150
#             H1: µ < 150
#
#
# - Step 2 : Specify the level of significance (α) :
#
#             α=0.05
#
#
# - Step 3 : Compute the value of the Test Statistic :
#
#                  x̅ - μ
#             Z = --------
#                  σ / √n
#
#                  149 - 150
#             Z = ------------
#                 1.414 / √4
#
#
#             Z = -1.414
#
#
# - Step 4 : Compute the p-value.
#
#             For Z=-1.414, p-value = 0.07927 --> This is a left-tailed test, i.e. p-value =  0.07927
#
#
# - Step 5 : Determine whether to Reject Ho :
#
#     - Here p-value (p) of the case-study is lesser than level of significant (α), i.e. p-value (0.07927) < α (0.05). We Reject Ho.
#
#
# <b> There is no sufficient statistical evidence to infer that the null hypothesis is true (i.e. the average volume min of 150 ml)

# %% [markdown]
# ### If the sample data is given and sample mean is not given :

# %% [markdown]
# 4. A machine is producing perfume bottles with the long term average of 150 ml and the standard deviation of 1.414 ml. Four bottles were picked and the data as 147, 151, 149 and 149 ml. Has the average volume min of 150 ml ? Test with 95% confidence level.
#
#
# <b> Ans :
# - Here,
#
#     - Random sample (n)=4
#     - Sample data = 147, 151, 149, 149
#     - Population mean (μ)=150
#     - Standard deviation (σ)=1.414
#     - level of significant (α)=0.05
#     - Null Hypothesis Ho: µ ≥ 150
#     - Alternative Hypothesis H1: µ < 150

# %%
# import the ztest from statsmodels.stats.weightstats.
from statsmodels.stats.weightstats import ztest

# import numpy as np.
import numpy as np

# Perform the ztest. Create the np.array as "x1" with passed data.
# pass the value parameter = 150.
# pass the alternative = "smaller".
# And pass the ddof = 0
# passed mean value in the null hypothesis, in alternative hypothesis we check whether the
# mean is larger
ztest, pval = ztest(x1 = np.array([147,151,149,149]),
                    value = 150,
                    alternative = "smaller",
                    ddof = 0)

# Print the p-value.
print("p-value :",float(pval))

# Print the z-test ststs value.
print("z-test value :",float(ztest))

# If p-value is lesser than the alpha value, then reject the Null Hypothesis.
if(pval <  0.05):
  print("We Reject the Null Hypothesis")

# If p-value is greater than the alpha value, then fail to reject the Null Hypothesis.
else:
  print("We fail to Reject the NUll Hypothesis")
# Out:
# p-value : 0.07864960352514258
# z-test value : -1.414213562373095
# We fail to Reject the NUll Hypothesis

# %% [markdown]
# <b> There is no sufficient statistical evidence to infer that the null hypothesis is true (i.e. the average volume min of 150 ml)
