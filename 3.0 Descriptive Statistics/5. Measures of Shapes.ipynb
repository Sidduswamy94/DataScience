# %% [markdown]
# # <p style='text-align: center;'> Measures of Shapes </p>

# %% [markdown]
# ## Measures of Shape :
# - Measures of shape describe the distribution (or pattern) of the data within a dataset.
#
#
# - The distribution shape of quantitative data can be described as there is a logical order to the values, and the 'low' and
#   'high' end values on the x-axis of the histogram are able to be identified.
#
#
# - The distribution shape of a qualitative data cannot be described as the data are not numeric.
#
#
# ## Types of Measures of Shape :
# - The Measures of Shape is divided into two parts :
#
#              1) symmetrical distribution (normal distribution)
#              2) asymmetrical distribution (skewed distribution)

# %% [markdown]
# ### 1) symmetrical distribution (normal distribution) :
# - In a symmetrical distribution the two sides of the distribution are a mirror image of each other.
#
#
# - A normal distribution is a true symmetric distribution of observed values. A symmetrical distribution is also calles as
#   normal distribution.
#
#
# --------------------------------------
# <b> Example :
# --------------------------------------
# Q) We are having 50 students height (in cm) data, from the data find the probability with interval of 1 cm and draw the histogram graph.
#
#
# - The following Histogram Graph is an example of a normal (symmetrical) distribution :
#
#
# ![image.png](attachment:image.png)
#
#
# - If represented as a 'normal curve' (or bell curve) the graph would take the following shape (where µ = mean, and σ = standard
#   deviation):
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <b> Key features of the normal (Symmetrical) distribution:
#
# - symmetrical shape
# - mode, median and mean are the same and are together in the centre of the curve
# - there can only be one mode (i.e. there is only one value which is most frequently observed)
# - most of the data are clustered around the centre, while the more extreme values on either side of the centre become less rare
#   as the distance from the centre increases (i.e. About 68% of values lie within one standard deviation (σ) away from the mean;
#   about 95% of the values lie within two standard deviations; and about 99.7% are within three standard deviations. This is
#   known as the empirical rule or the 3-sigma rule.)

# %% [markdown]
# ### 2) asymmetrical distribution (skewed distribution) :
# - In an asymmetrical distribution the two sides will not be mirror images of each other.
#
#
# - Skewness is the tendency for the values to be more frequent around the high or low ends of the x-axis.
#
#
# - When a histogram is constructed for skewed data it is possible to identify skewness by looking at the shape of the
#   distribution.
#
#
# ---------------------
# <b> For example :
# ---------------------
# - A distribution is said to be positively skewed (skewed to be right) when the tail on the right side of the histogram is
#   longer than the left side. Most of the values tend to cluster toward the left side of the x-axis (i.e. the smaller values)
#   with increasingly fewer values at the right side of the x-axis (i.e. the larger values).
#
#
# ![image.png](attachment:image.png)
#
#
# - A distribution is said to be negatively skewed (skewed to be left) when the tail on the left side of the histogram is longer
#   than the right side. Most of the values tend to cluster toward the right side of the x-axis (i.e. the larger values), with
#   increasingly less values on the left side of the x-axis (i.e. the smaller values).
#
#
# ![image-2.png](attachment:image-2.png)
#
#
#
# <b> Key features of the skewed distribution:
#
# - asymmetrical shape.
# - mean and median have different values and do not all lie at the centre of the curve.
# - For positively skewed (skewed to be right) the Mean is greater than the Median.
# - For negative skewed (skewed to be left) the Mean is lesser than the Median.
# - there can be more than one mode.
# - the distribution of the data tends towards the high or low end of the dataset.

# %% [markdown]
# # <p style='text-align: center;'> Kurtosis </p>

# %% [markdown]
# - Kurtosis is a measure of the tailedness (peakedness) of a distribution. Tailedness is how often outliers occur.
#
#
# - There are 3 types in Kurtosis, they are :
#
#
#      1) leptokurtic (high & thin) : Distributions with high kurtosis (flat tails) are leptokurtic.
#
#
#      2) mesokurtic (normal in shape) : Distributions with medium kurtosis (medium tails) are mesokurtic.
#
#
#      3) platykurtic (flat & spread out) : Distributions with low kurtosis (thin tails) are platykurtic.

# %% [markdown]
# <b> Graphical example of types of kurtosis :
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <b> Kurtosis can take several values :
#
#
# - Positive excess kurtosis – when excess kurtosis, given by (kurtosis – 3), is positive, then the distribution has a sharp peak
#   and is called a leptokurtic distribution.
#
#
# - Negative excess kurtosis – when excess kurtosis, given by (kurtosis – 3), is negative, then the distribution has a flat peak
#   and is called a platykurtic distribution.
#
#
# - Zero excess kurtosis – when excess kurtosis, given by (kurtosis – 3), is zero, then the distribution follows a normal
#   distribution and is also called a mesokurtic distribution.

# %% [markdown]
# <b> Here is a summary of what is mentioned above in a table format :
#
# ![image.png](attachment:image.png)
