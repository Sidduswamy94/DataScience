# %% [markdown]
# # <p style='text-align: center;'> Probability Distribution </p>

# %% [markdown]
# ## Probability Distribution :
# - Graphical representation of variable and respective probabilities of variables.
#
#
# ## Frequency Distribution Vs Probability Distribution :
# - The frequency distribution, y-axis represents the frequency (number of counts of an outcome).
#
#
# - The probability distribution, y-axis represents the probability (probability of an outcome).
#
#
# - In both distributions x-axis remains same data.
#
#
# ## Types of Probability Distribution :
# - The probability distribution is divided into two parts :
#
#                  1) Discrete Probability Distributions.
#                  2) Continuous Probability Distributions.

# %% [markdown]
# ## 1) Discrete Probability Distributions :
# - A discrete probability distribution describes the probability of occurrence of each value of a discrete random variable.
#
#
# - If a random variable is a discrete variable, its probability distribution is called a discrete probability distribution.
#
# --------------------
# <b> Example
# --------------------
# Q) We are having 20 days daily sales of Tvs data, from the data find i) what is probability of sale ? ii) what is probability of salling at least 3 Tvs ?
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <b> Ans : -
#
#
# - <b> Probability of "0" Tvs selling,
#
#
#                                             Number of days with Zero Tvs selling
#      Probability of "0" Tvs selling, P(0) = ------------------------------------
#                                                   Total Number of days
#
#
#                                                             8
#      Probability of "0" Tvs selling, P(0) = ------------------------------------
#                                                             20
#
#
#                                                            2
#      Probability of "0" Tvs selling, P(0) = ------------------------------------
#                                                            5
#
#
#
#      So, Probability of "0" Tvs selling, P(0) =  0.40
#
#
#
# - <b> Probability of "1" Tvs selling,
#
#
#
#                                             Number of days with One Tvs selling
#      Probability of "1" Tvs selling, P(1) = ------------------------------------
#                                                     Total Number of days
#
#
#                                                            5
#      Probability of "1" Tvs selling, P(1) = ------------------------------------
#                                                            20
#
#
#                                                            1
#      Probability of "1" Tvs selling, P(1) = ------------------------------------
#                                                            4
#
#
#
#      So, Probability of "1" Tvs selling, P(1) =  0.25
#
#
#
# - <b> Probability of "2" Tvs selling,
#
#
#
#                                             Number of days with Two Tvs selling
#      Probability of "2" Tvs selling, P(2) = ------------------------------------
#                                                     Total Number of days
#
#
#                                                             4
#      Probability of "2" Tvs selling, P(2) = ------------------------------------
#                                                             20
#
#
#                                                            1
#      Probability of "2" Tvs selling, P(2) = ------------------------------------
#                                                            5
#
#
#
#      So, Probability of "2" Tvs selling, P(2) =  0.20
#
#
#
# - <b> Probability of "3" Tvs selling,
#
#
#
#                                             Number of days with Three Tvs selling
#      Probability of "3" Tvs selling, P(3) = -------------------------------------
#                                                      Total Number of days
#
#
#                                                             1
#      Probability of "3" Tvs selling, P(3) = -------------------------------------
#                                                             20
#
#
#      So, Probability of "3" Tvs selling, P(3) =  0.05
#
#
#
# - <b> Probability of "4" Tvs selling,
#
#
#
#                                             Number of days with Four Tvs selling
#      Probability of "4" Tvs selling, P(4) = ------------------------------------
#                                                      Total Number of days
#
#
#                                                             2
#      Probability of "4" Tvs selling, P(4) = ------------------------------------
#                                                             20
#
#
#                                                            1
#      Probability of "4" Tvs selling, P(4) = ------------------------------------
#                                                            10
#
#
#
#      So, Probability of "4" Tvs selling, P(4) =  0.10
#
#
# - <b> Graphical representation of selling Tvs :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - <b> i) what is probability of sale :
#
#
#     Probability of sale, P(s) = P(1) + P(2) + P(3) + P(4)
#
#
#     Probability of sale, P(s) = 0.25 + 0.20 + 0.05 + 0.10
#
#
#     Probability of sale, P(s) = 0.60
#
#
# - <b> ii) what is probability of salling at least 3 Tvs :
#
#
#     probability of salling at least 3 Tvs, P(T) = P(3) + P(4)
#
#
#     probability of salling at least 3 Tvs, P(T) = 0.05 + 0.10
#
#
#     probability of salling at least 3 Tvs, P(T) = 0.15

# %% [markdown]
# ## 2) Continuous Probability Distributions :
# - A continuous distribution describes the probabilities of a continuous random variable's possible values.
#
#
# - If a random variable is a continuous variable, its probability distribution is called a continuous probability distribution.

# %% [markdown]
# --------------------------------
# <b> Example :
# --------------------------------
# Q) We are having 20 students weight (in lbs) data, from the data find the probability with interval of 10 lbs and draw the histogram graph.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <b> Ans : -
#
#
# - <b> Probability of the students, weight between "90 to 100 lbs",
#
#
#
#                      Number of students, weight between "90 to 100 lbs"
#            P(z1) = ----------------------------------------------------
#                                  Total Number of students
#
#
#                                           5
#            P(z1) = ----------------------------------------------------
#                                          20
#
#
#
#            P(z1) = 0.25
#
#
# - <b> Probability of the students, weight between "100 to 110 lbs",
#
#
#
#                      Number of students, weight between "100 to 110 lbs"
#             P(z2) = ----------------------------------------------------
#                                     Total Number of students
#
#
#                                             6
#             P(z2) = ----------------------------------------------------
#                                             20
#
#
#
#             P(z2) = 0.30
#
#
# - <b> Probability of the students, weight between "110 to 120 lbs",
#
#
#
#                      Number of students, weight between "110 to 120 lbs"
#             P(z3) = ----------------------------------------------------
#                                     Total Number of students
#
#
#                                            4
#             P(z3) = ----------------------------------------------------
#                                           20
#
#
#
#             P(z3) = 0.20
#
#
# - <b> Probability of the students, weight between "120 to 130 lbs",
#
#
#
#                      Number of students, weight between "120 to 130 lbs"
#             P(z4) = ----------------------------------------------------
#                                    Total Number of students
#
#
#                                         3
#             P(z4) = ----------------------------------------------------
#                                        20
#
#
#
#             P(z4) = 0.15
#
#
# - <b> Probability of the students, weight between "130 to 140 lbs",
#
#
#
#                      Number of students, weight between "130 to 140 lbs"
#             P(z1) = ----------------------------------------------------
#                                    Total Number of students
#
#
#                                            2
#             P(z1) = ----------------------------------------------------
#                                            20
#
#
#
#             P(z1) = 0.10
#
#
# - <b> Graphical representation of students Probability Distributions :
#
#
# ![image.png](attachment:image.png)
